# %%
import pandas as pd
import locale
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' )
df = pd.read_json("spider_data_4.json")

# %%
# Read JSON & Rearrange df columns
cols = ['rank', 'video_game','company_genre', 'year','console', 'weeks_out','yearly_sale', 'total_sale']

df_2 = df[cols]
globall = pd.read_json("spider_data_global.json")
global_2 = globall[cols]
japan = pd.read_json("spider_data_japan.json")
japan_2 = japan[cols]
usa = pd.read_json("spider_data_usa.json")
usa_2 = usa[cols]
europe = pd.read_json("spider_data_europe.json")
europe_2 = europe[cols]

# %%
# Removes commas from yearly sale numbers & total sales numbers
df_2['yearly_sale'] = list(map(locale.atoi,df_2['yearly_sale']))
global_2['yearly_sale'] = list(map(locale.atoi,global_2['yearly_sale']))
usa_2['yearly_sale'] = list(map(locale.atoi,usa_2['yearly_sale']))
japan_2['yearly_sale'] = list(map(locale.atoi,japan_2['yearly_sale']))
europe_2['yearly_sale'] = list(map(locale.atoi,europe_2['yearly_sale']))
usa_2['total_sale'] = list(map(locale.atoi,usa_2['total_sale']))
japan_2['total_sale'] = list(map(locale.atoi,japan_2['total_sale']))
europe_2['total_sale'] = list(map(locale.atoi,europe_2['total_sale']))
# Out:
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# Determine the yearly sale's mean to replace N/A values (assumption that yearly sale should = total sale)
global_na = global_2[global_2['total_sale'] == 'N/A']
global_na['yearly_sale'].mean()
# Out:
# 720237.3

# %%
# Replace N/A Values
global_2['total_sale'] = global_2['total_sale'].replace('N/A','720237')
# Out:
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Remove commas from total_sale after value replacement
global_2['total_sale'] = list(map(locale.atoi,global_2['total_sale']))
# Out:
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Determine the yearly sale's mean to replace N/A values (assumption that yearly sale should = total sale)
df_na = df_2[df_2['total_sale'] == 'N/A']
df_na['yearly_sale'].mean()
# Out:
# 870928.4285714285

# %%
# Replace N/A Values
df_2['total_sale'] = df_2['total_sale'].replace('N/A','870928')

# %%
# Remove commas from total_sale after value replacement
df_2['total_sale'] = list(map(locale.atoi,df_2['total_sale']))

# %% [markdown]
# # Dataframes

# %%
df_2.head()
# Out:
#    rank                                    video_game  \
# 0     1                                    Nintendogs
# 1     2                         New Super Mario Bros.
# 2     3                                  Gears of War
# 3     4                                 Madden NFL 07
# 4     5  Brain Age: Train Your Brain in Minutes a Day
#
#              company_genre  year  console  weeks_out  yearly_sale  total_sale
# 0     Nintendo, Simulation  2006     (DS)         71      2109928     3594975
# 1       Nintendo, Platform  2006     (DS)         33      1913739     1913739
# 2       Microsoft, Shooter  2006   (X360)          8      1785997     1785997
# 3  Electronic Arts, Sports  2006   (X360)         19      1160526     1160526
# 4           Nintendo, Misc  2006     (DS)         37      1075980     1075980

# %%
global_2.head()
# Out:
#    rank                                    video_game           company_genre  \
# 0     1                         New Super Mario Bros.      Nintendo, Platform
# 1     2                                    Nintendogs    Nintendo, Simulation
# 2     3  Brain Age: Train Your Brain in Minutes a Day          Nintendo, Misc
# 3     4                   Animal Crossing: Wild World    Nintendo, Simulation
# 4     5               Pokemon Diamond / Pearl Version  Nintendo, Role-Playing
#
#    year console  weeks_out  yearly_sale  total_sale
# 0  2006    (DS)         33      8001240     8001240
# 1  2006    (DS)         89      6635061    11357755
# 2  2006    (DS)         85      5039142     6261534
# 3  2006    (DS)         58      4676484     6376376
# 4  2006    (DS)         15      4473692     4473692

# %%
usa_2.head()
# Out:
#    rank                                    video_game  \
# 0     1                                    Nintendogs
# 1     2                         New Super Mario Bros.
# 2     3                                  Gears of War
# 3     4                                 Madden NFL 07
# 4     5  Brain Age: Train Your Brain in Minutes a Day
#
#              company_genre  year  console  weeks_out  yearly_sale  total_sale
# 0     Nintendo, Simulation  2006     (DS)         71      2109928     3594975
# 1       Nintendo, Platform  2006     (DS)         33      1913739     1913739
# 2       Microsoft, Shooter  2006   (X360)          8      1785997     1785997
# 3  Electronic Arts, Sports  2006   (X360)         19      1160526     1160526
# 4           Nintendo, Misc  2006     (DS)         37      1075980     1075980

# %%
europe_2.head()
# Out:
#    rank                                    video_game         company_genre  \
# 0     1                                    Nintendogs  Nintendo, Simulation
# 1     2  Brain Age: Train Your Brain in Minutes a Day        Nintendo, Misc
# 2     3                         New Super Mario Bros.    Nintendo, Platform
# 3     4                   Animal Crossing: Wild World  Nintendo, Simulation
# 4     5                                 Mario Kart DS      Nintendo, Racing
#
#    year console  weeks_out  yearly_sale  total_sale
# 0  2006    (DS)         65      3151987     4740282
# 1  2006    (DS)         30      1542559     1542557
# 2  2006    (DS)         27      1472240     1472241
# 3  2006    (DS)         40      1169228     1169230
# 4  2006    (DS)         58       963501     1742658

# %%
japan_2.head()
# Out:
#    rank                                   video_game  \
# 0     1              Pokemon Diamond / Pearl Version
# 1     2                        New Super Mario Bros.
# 2     3  Brain Age 2: More Training in Minutes a Day
# 3     4                  Animal Crossing: Wild World
# 4     5                            Final Fantasy XII
#
#                company_genre  year console  weeks_out  yearly_sale  total_sale
# 0     Nintendo, Role-Playing  2006    (DS)         15      4473692     4473692
# 1         Nintendo, Platform  2006    (DS)         32      3960355     3960355
# 2             Nintendo, Misc  2006    (DS)         53      3410055     3837386
# 3       Nintendo, Simulation  2006    (DS)         58      2412341     3814703
# 4  Square Enix, Role-Playing  2006   (PS2)         42      2324803     2324803

# %%
# Split company/genre column into two cols [company,genre]
company_genre = global_2["company_genre"].str.split(", ", n = 1, expand = True)

# %%
# Splitting company genre column into new cols
global_2["company"] = company_genre[0]
global_2["genre"] = company_genre[1]
global_2.drop(columns =["company_genre"], inplace = True)

global_2 = global_2.drop_duplicates()
global_2.describe()
# Out:
#               rank         year    weeks_out   yearly_sale    total_sale
# count  1300.000000  1300.000000  1300.000000  1.300000e+03  1.300000e+03
# mean     50.500000  2012.000000    50.782308  2.017741e+06  4.101365e+06
# std      28.877179     3.743097    52.921263  2.126147e+06  6.514262e+06
# min       1.000000  2006.000000     1.000000  2.598060e+05  2.598060e+05
# 25%      25.750000  2009.000000    13.000000  9.398298e+05  1.121182e+06
# 50%      50.500000  2012.000000    39.500000  1.318636e+06  2.094748e+06
# 75%      75.250000  2015.000000    62.000000  2.183179e+06  4.383053e+06
# max     100.000000  2018.000000   372.000000  2.184201e+07  8.179879e+07

# %%
# Splitting company genre column into new cols
company_genre_usa = usa_2["company_genre"].str.split(", ", n = 1, expand = True) 
usa_2["company"] = company_genre_usa[0]
usa_2["genre"] = company_genre_usa[1]
usa_2.drop(columns =["company_genre"], inplace = True)

# Drop duplicates
usa_2 = usa_2.drop_duplicates()
usa_2.describe()
# Out:
#               rank         year    weeks_out   yearly_sale    total_sale
# count  1300.000000  1300.000000  1300.000000  1.300000e+03  1.300000e+03
# mean     50.500000  2012.000000    48.732308  8.616822e+05  1.713500e+06
# std      28.877179     3.743097    52.800792  9.319678e+05  2.863925e+06
# min       1.000000  2006.000000     0.000000  1.555710e+05  1.555710e+05
# 25%      25.750000  2009.000000    13.000000  3.944572e+05  4.707065e+05
# 50%      50.500000  2012.000000    37.000000  5.593070e+05  8.626990e+05
# 75%      75.250000  2015.000000    61.000000  9.449058e+05  1.843322e+06
# max     100.000000  2018.000000   372.000000  9.669407e+06  3.772361e+07

# %%
len(usa_2)
# Out:
# 1300

# %%
# Splitting company genre column into new cols
company_genre_europe = europe_2["company_genre"].str.split(", ", n = 1, expand = True) 
europe_2["company"] = company_genre_europe[0]
europe_2["genre"] = company_genre_europe[1]
europe_2.drop(columns =["company_genre"], inplace = True)

# Drop duplicates
europe_2 = europe_2.drop_duplicates()
europe_2.describe()
# Out:
#               rank         year    weeks_out   yearly_sale    total_sale
# count  1279.000000  1279.000000  1279.000000  1.279000e+03  1.279000e+03
# mean     49.851446  2012.098514    48.198593  7.218357e+05  1.455310e+06
# std      28.651920     3.693202    51.782375  8.359034e+05  2.312873e+06
# min       1.000000  2006.000000     2.000000  1.519100e+04  1.519000e+04
# 25%      25.000000  2009.000000    12.000000  3.255260e+05  3.872075e+05
# 50%      50.000000  2012.000000    36.000000  4.593490e+05  7.204040e+05
# 75%      74.000000  2015.000000    62.000000  7.666700e+05  1.595256e+06
# max     100.000000  2018.000000   370.000000  8.072913e+06  2.864415e+07

# %%
# Splitting company genre column into new cols
company_genre_japan = japan_2["company_genre"].str.split(", ", n = 1, expand = True) 
japan_2["company"] = company_genre_japan[0]
japan_2["genre"] = company_genre_japan[1]
japan_2.drop(columns =["company_genre"], inplace = True)

# %%
# Drop duplicates
japan_2 = japan_2.drop_duplicates()
japan_2.describe()
# Out:
#               rank         year    weeks_out   yearly_sale    total_sale
# count  1300.000000  1300.000000  1300.000000  1.300000e+03  1.300000e+03
# mean     50.500000  2012.000000    40.850000  3.490372e+05  6.428240e+05
# std      28.877179     3.743097    44.247239  4.922318e+05  1.007430e+06
# min       1.000000  2006.000000   -39.000000  5.244700e+04  5.246600e+04
# 25%      25.750000  2009.000000    14.000000  1.382062e+05  1.523692e+05
# 50%      50.500000  2012.000000    32.000000  1.950615e+05  2.413725e+05
# 75%      75.250000  2015.000000    48.250000  3.408665e+05  5.590478e+05
# max     100.000000  2018.000000   423.000000  5.050908e+06  6.408117e+06

# %%
# Splitting company genre column into new cols
company_genre_df_2 = df_2["company_genre"].str.split(", ", n = 1, expand = True) 
df_2["company"] = company_genre_df_2[0]
df_2["genre"] = company_genre_df_2[1]
df_2.drop(columns =["company_genre"], inplace = True)

# %%
# Drop duplicates
df_2 = df_2.drop_duplicates()
df_2.describe()
# Out:
#               rank         year    weeks_out   yearly_sale    total_sale
# count  2600.000000  2600.000000  2600.000000  2.600000e+03  2.600000e+03
# mean     50.500000  2012.000000    49.757308  1.439712e+06  2.907838e+06
# std      28.871623     3.742377    52.860834  1.740041e+06  5.170436e+06
# min       1.000000  2006.000000     0.000000  1.555710e+05  1.555710e+05
# 25%      25.750000  2009.000000    13.000000  5.263585e+05  7.267040e+05
# 50%      50.500000  2012.000000    38.000000  9.416465e+05  1.379806e+06
# 75%      75.250000  2015.000000    61.000000  1.581677e+06  2.999829e+06
# max     100.000000  2018.000000   372.000000  2.184201e+07  8.179879e+07

# %% [markdown]
# # Genre & Console Frequency by Region

# %%
def value_counts_df(df, col):
    df = pd.DataFrame(df[col].value_counts())
    df.index.name = col
    df.columns = ['count']
    return df

# %%
# Compare year2 - year1 delta %
def difference(df1,df2):
    return df2-df1

# %% [markdown]
# ## Overall Dataframe (Global, USA, Japan, Europe)

# %%
#Overall Console
value_counts_df(df_2,'console')
# Out:
#          count
# console
#  (X360)    544
#  (PS4)     405
#  (PS3)     375
#  (Wii)     296
#  (DS)      289
#  (XOne)    269
#  (3DS)     150
#  (PSP)      89
#  (NS)       79
#  (WiiU)     58
#  (PC)       44
#  (PSV)       2

# %%
# Overall Genre
value_counts_df(df_2, 'genre')
# Out:
#                   count
# genre
# Action              535
# Shooter             465
# Sports              395
# Role-Playing        299
# Misc                226
# Platform            176
# Racing              151
# Fighting             98
# Adventure            92
# Simulation           83
# Action-Adventure     28
# Puzzle               24
# Strategy             18
# Party                 6
# Music                 3
# Sandbox               1

# %%
df_2006 = pd.DataFrame(df_2[df_2['year'] == 2006]['genre'].value_counts())
df_2007 = pd.DataFrame(df_2[df_2['year'] == 2007]['genre'].value_counts())
df_2008 = pd.DataFrame(df_2[df_2['year'] == 2008]['genre'].value_counts())
df_2009 = pd.DataFrame(df_2[df_2['year'] == 2009]['genre'].value_counts())
df_2010 = pd.DataFrame(df_2[df_2['year'] == 2010]['genre'].value_counts())
df_2011 = pd.DataFrame(df_2[df_2['year'] == 2011]['genre'].value_counts())
df_2012 = pd.DataFrame(df_2[df_2['year'] == 2012]['genre'].value_counts())
df_2013 = pd.DataFrame(df_2[df_2['year'] == 2013]['genre'].value_counts())
df_2014 = pd.DataFrame(df_2[df_2['year'] == 2014]['genre'].value_counts())
df_2015 = pd.DataFrame(df_2[df_2['year'] == 2015]['genre'].value_counts())
df_2016 = pd.DataFrame(df_2[df_2['year'] == 2016]['genre'].value_counts())
df_2017 = pd.DataFrame(df_2[df_2['year'] == 2017]['genre'].value_counts())
df_2018 = pd.DataFrame(df_2[df_2['year'] == 2018]['genre'].value_counts())
df2_list = [df_2006,df_2007,df_2008,df_2009,df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016,df_2017,df_2018]

# %%
years = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']

# %%
df_c = pd.concat([(df_2007-df_2006)/df_2006,
           (df_2008-df_2007)/df_2007,
           (df_2009-df_2008)/df_2008,
           (df_2010-df_2009)/df_2009,
           (df_2011-df_2010)/df_2010,
           (df_2012-df_2011)/df_2011,
           (df_2013-df_2012)/df_2012,
           (df_2014-df_2013)/df_2013,
           (df_2015-df_2014)/df_2014,
           (df_2016-df_2015)/df_2015,
           (df_2017-df_2016)/df_2016,
           (df_2018-df_2017)/df_2017],axis=1,sort=False)
df_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Action           -0.200000  0.750000  0.071429  0.100000  0.121212  0.702703
# Adventure         0.833333  0.181818 -0.076923 -0.166667 -0.500000 -0.800000
# Fighting         -0.500000 -0.166667  2.200000 -0.687500  0.400000 -0.857143
# Misc              0.937500  0.387097 -0.534884  0.100000  0.000000 -0.409091
# Platform          0.437500 -0.260870 -0.411765  0.800000 -0.166667 -0.400000
# Puzzle           -0.333333       NaN       NaN  1.500000 -0.600000       NaN
# Racing           -0.250000 -0.533333  0.571429  0.181818 -0.153846  0.272727
# Role-Playing      0.222222 -0.272727  0.437500  0.086957 -0.320000  0.647059
# Shooter          -0.032258 -0.066667  0.035714  0.068966  0.387097 -0.139535
# Simulation        0.000000  0.133333 -0.588235 -0.571429  0.000000  0.000000
# Sports           -0.228571 -0.037037  0.461538 -0.131579  0.151515 -0.210526
# Strategy               NaN       NaN       NaN  0.000000       NaN       NaN
# Action-Adventure       NaN       NaN       NaN       NaN       NaN       NaN
# Music                  NaN       NaN       NaN       NaN       NaN       NaN
# Party                  NaN       NaN       NaN       NaN       NaN       NaN
# Sandbox                NaN       NaN       NaN       NaN       NaN       NaN
#
#                      genre     genre     genre     genre     genre     genre
# Action            0.095238  0.057971 -0.342466  0.020833 -0.285714 -0.028571
# Adventure         6.000000  0.571429 -0.545455  0.400000 -0.714286  0.000000
# Fighting          2.000000  0.333333  1.250000 -0.222222  0.571429  0.090909
# Misc             -0.384615 -0.625000  3.666667  0.571429 -0.727273  0.000000
# Platform          0.777778 -0.125000 -0.428571 -0.375000  0.600000  1.125000
# Puzzle                 NaN       NaN       NaN       NaN       NaN  0.000000
# Racing           -0.285714  0.000000 -0.100000 -0.222222  0.857143 -0.153846
# Role-Playing     -0.321429  0.000000  0.315789  0.040000  0.500000 -0.435897
# Shooter           0.000000 -0.027027  0.305556 -0.085106  0.000000 -0.302326
# Simulation       -0.333333  0.000000  2.000000 -0.166667 -0.400000 -0.333333
# Sports           -0.166667  0.120000  0.035714  0.000000 -0.034483  0.035714
# Strategy          2.000000       NaN       NaN       NaN       NaN -0.333333
# Action-Adventure       NaN       NaN       NaN       NaN       NaN  5.000000
# Music                  NaN       NaN       NaN       NaN       NaN  1.000000
# Party                  NaN       NaN       NaN       NaN       NaN  1.000000
# Sandbox                NaN       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# ## USA Dataframe

# %%
usa_2006 = usa_2[usa_2['year'] == 2006]['genre'].value_counts()
usa_2007 = usa_2[usa_2['year'] == 2007]['genre'].value_counts()
usa_2008 = usa_2[usa_2['year'] == 2008]['genre'].value_counts()
usa_2009 = usa_2[usa_2['year'] == 2009]['genre'].value_counts()
usa_2010 = usa_2[usa_2['year'] == 2010]['genre'].value_counts()
usa_2011 = usa_2[usa_2['year'] == 2011]['genre'].value_counts()
usa_2012 = usa_2[usa_2['year'] == 2012]['genre'].value_counts()
usa_2013 = usa_2[usa_2['year'] == 2013]['genre'].value_counts()
usa_2014 = usa_2[usa_2['year'] == 2014]['genre'].value_counts()
usa_2015 = usa_2[usa_2['year'] == 2015]['genre'].value_counts()
usa_2016 = usa_2[usa_2['year'] == 2016]['genre'].value_counts()
usa_2017 = usa_2[usa_2['year'] == 2017]['genre'].value_counts()
usa_2018 = usa_2[usa_2['year'] == 2018]['genre'].value_counts()
usa_list = [usa_2006,usa_2007,usa_2008,usa_2009,usa_2010,usa_2011,usa_2012,usa_2013,usa_2014,usa_2015,usa_2016,usa_2017,usa_2018]

# %%
usa_c = pd.concat([(usa_2007-usa_2006)/usa_2006,
                   (usa_2008-usa_2007)/usa_2007,
                   (usa_2009-usa_2008)/usa_2008,
                   (usa_2010-usa_2009)/usa_2009,
                   (usa_2011-usa_2010)/usa_2010,
                   (usa_2012-usa_2011)/usa_2011,
                   (usa_2013-usa_2012)/usa_2012,
                   (usa_2014-usa_2013)/usa_2013,
                   (usa_2015-usa_2014)/usa_2014,
                   (usa_2016-usa_2015)/usa_2015,
                   (usa_2017-usa_2016)/usa_2016,
                   (usa_2018-usa_2017)/usa_2017],axis=1,sort=False)

# %%
# Drop cols
usa_c = usa_c.drop(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform','Puzzle', 'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports'],axis=1)
usa_c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1334-e7f8ab4afb68> in <module>
#       1 # Yearly percent change & Drop cols
# ----> 2 usa_c = usa_c.drop(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform','Puzzle', 'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports'],axis=1)
#       3 usa_c
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3829                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3830                 if errors == 'raise' and labels_missing:
# -> 3831                     raise KeyError('{} not found in axis'.format(labels))
#    3832
#    3833             slicer = [slice(None)] * self.ndim
#
# KeyError: "['Action' 'Adventure' 'Fighting' 'Misc' 'Platform' 'Puzzle' 'Racing'\n 'Role-Playing' 'Shooter' 'Simulation' 'Sports'] not found in axis"

# %%
# Yearly percent change
usa_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Action           -0.181818  0.444444  0.307692  0.058824  0.000000  0.888889
# Adventure         0.666667  0.200000 -0.166667 -0.200000 -0.500000       NaN
# Fighting         -0.500000  0.000000  1.333333 -0.571429  0.333333 -0.750000
# Misc              3.000000  0.312500 -0.428571 -0.166667  0.000000 -0.300000
# Platform          0.333333 -0.333333 -0.375000  0.800000 -0.111111 -0.375000
# Puzzle            0.000000       NaN       NaN  3.000000 -0.750000       NaN
# Racing           -0.416667 -0.428571  0.000000  0.250000  0.000000  0.400000
# Role-Playing      0.333333 -0.250000  0.500000  0.000000  0.000000  0.555556
# Shooter          -0.117647  0.000000  0.000000  0.133333  0.294118 -0.136364
# Simulation        0.000000  0.285714 -0.666667  0.000000 -0.666667       NaN
# Sports           -0.238095 -0.062500  0.400000 -0.190476  0.176471 -0.350000
# Strategy               NaN       NaN       NaN  0.000000       NaN       NaN
# Action-Adventure       NaN       NaN       NaN       NaN       NaN       NaN
# Music                  NaN       NaN       NaN       NaN       NaN       NaN
# Party                  NaN       NaN       NaN       NaN       NaN       NaN
#
#                      genre     genre     genre     genre     genre     genre
# Action            0.029412  0.057143 -0.432432  0.238095 -0.384615  0.062500
# Adventure              NaN  1.000000 -0.500000  0.333333 -0.750000  0.000000
# Fighting          0.000000  1.000000  1.000000  0.000000  0.500000  0.166667
# Misc             -0.428571 -0.500000  2.500000  0.428571 -0.800000  0.000000
# Platform          0.600000 -0.125000 -0.428571 -0.500000  1.000000  1.000000
# Puzzle                 NaN       NaN       NaN       NaN       NaN  0.000000
# Racing           -0.428571  0.000000  0.000000 -0.250000  1.333333 -0.285714
# Role-Playing     -0.357143 -0.111111  0.625000 -0.076923  0.583333 -0.473684
# Shooter           0.000000  0.000000  0.315789 -0.120000 -0.045455 -0.190476
# Simulation             NaN       NaN  1.000000 -0.500000  0.000000       NaN
# Sports            0.153846 -0.066667  0.214286 -0.058824  0.000000  0.000000
# Strategy               NaN       NaN       NaN       NaN       NaN -0.500000
# Action-Adventure       NaN       NaN       NaN       NaN       NaN  5.000000
# Music                  NaN       NaN       NaN       NaN       NaN  0.000000
# Party                  NaN       NaN       NaN       NaN       NaN  1.000000

# %%
# Yearly difference in genre in top 100
np.diff(usa_list)
# Out:
# array([Action          -2.0
# Adventure        2.0
# Fighting        -3.0
# Misc            12.0
# Platform         3.0
# Puzzle           0.0
# Racing          -5.0
# Role-Playing     2.0
# Shooter         -2.0
# Simulation       0.0
# Sports          -5.0
# Strategy         NaN
# Name: genre, dtype: float64,
#        Action          4.0
# Adventure       1.0
# Fighting        0.0
# Misc            5.0
# Platform       -4.0
# Puzzle          NaN
# Racing         -3.0
# Role-Playing   -2.0
# Shooter         0.0
# Simulation      2.0
# Sports         -1.0
# Name: genre, dtype: float64,
#        Action          4.0
# Adventure      -1.0
# Fighting        4.0
# Misc           -9.0
# Platform       -3.0
# Puzzle          NaN
# Racing          0.0
# Role-Playing    3.0
# Shooter         0.0
# Simulation     -6.0
# Sports          6.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action          1
# Adventure      -1
# Fighting       -4
# Misc           -2
# Platform        4
# Puzzle          3
# Racing          1
# Role-Playing    0
# Shooter         2
# Simulation      0
# Sports         -4
# Strategy        0
# Name: genre, dtype: int64,
#        Action          0.0
# Adventure      -2.0
# Fighting        1.0
# Misc            0.0
# Platform       -1.0
# Puzzle         -3.0
# Racing          0.0
# Role-Playing    0.0
# Shooter         5.0
# Simulation     -2.0
# Sports          3.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action          16.0
# Adventure        NaN
# Fighting        -3.0
# Misc            -3.0
# Platform        -3.0
# Puzzle           NaN
# Racing           2.0
# Role-Playing     5.0
# Shooter         -3.0
# Simulation       NaN
# Sports          -7.0
# Name: genre, dtype: float64,
#        Action          1.0
# Adventure       NaN
# Fighting        0.0
# Misc           -3.0
# Platform        3.0
# Racing         -3.0
# Role-Playing   -5.0
# Shooter         0.0
# Sports          2.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action          2.0
# Adventure       3.0
# Fighting        1.0
# Misc           -2.0
# Platform       -1.0
# Racing          0.0
# Role-Playing   -1.0
# Shooter         0.0
# Simulation      NaN
# Sports         -1.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action         -16
# Adventure       -3
# Fighting         2
# Misc             5
# Platform        -3
# Racing           0
# Role-Playing     5
# Shooter          6
# Simulation       1
# Sports           3
# Name: genre, dtype: int64,
#        Action          5
# Adventure       1
# Fighting        0
# Misc            3
# Platform       -2
# Racing         -1
# Role-Playing   -1
# Shooter        -3
# Simulation     -1
# Sports         -1
# Name: genre, dtype: int64,
#        Action             -10.0
# Action-Adventure     NaN
# Adventure           -3.0
# Fighting             2.0
# Misc                -8.0
# Music                NaN
# Party                NaN
# Platform             2.0
# Puzzle               NaN
# Racing               4.0
# Role-Playing         7.0
# Shooter             -1.0
# Simulation           0.0
# Sports               0.0
# Strategy             NaN
# Name: genre, dtype: float64,
#        Action               1.0
# Action-Adventure    10.0
# Adventure            0.0
# Fighting             1.0
# Misc                 0.0
# Music                0.0
# Party                1.0
# Platform             4.0
# Puzzle               0.0
# Racing              -2.0
# Role-Playing        -9.0
# Shooter             -4.0
# Simulation           NaN
# Sports               0.0
# Strategy            -1.0
# Name: genre, dtype: float64], dtype=object)

# %%
# Overall Console
value_counts_df(usa_2,'console')
# Out:
#          count
# console
#  (X360)    312
#  (PS4)     188
#  (PS3)     171
#  (Wii)     163
#  (XOne)    156
#  (DS)      130
#  (3DS)      62
#  (NS)       41
#  (PSP)      35
#  (WiiU)     28
#  (PC)       14

# %%
# Overall Genre
value_counts_df(usa_2, 'genre')
# Out:
#                   count
# genre
# Action              272
# Shooter             243
# Sports              217
# Role-Playing        132
# Misc                107
# Platform             89
# Racing               71
# Fighting             51
# Adventure            43
# Simulation           35
# Action-Adventure     14
# Puzzle               12
# Strategy              9
# Party                 3
# Music                 2

# %% [markdown]
# ## Europe Dataframe

# %%
europe_2006 = europe_2[europe_2['year'] == 2006]['genre'].value_counts()
europe_2007 = europe_2[europe_2['year'] == 2007]['genre'].value_counts()
europe_2008 = europe_2[europe_2['year'] == 2008]['genre'].value_counts()
europe_2009 = europe_2[europe_2['year'] == 2009]['genre'].value_counts()
europe_2010 = europe_2[europe_2['year'] == 2010]['genre'].value_counts()
europe_2011 = europe_2[europe_2['year'] == 2011]['genre'].value_counts()
europe_2012 = europe_2[europe_2['year'] == 2012]['genre'].value_counts()
europe_2013 = europe_2[europe_2['year'] == 2013]['genre'].value_counts()
europe_2014 = europe_2[europe_2['year'] == 2014]['genre'].value_counts()
europe_2015 = europe_2[europe_2['year'] == 2015]['genre'].value_counts()
europe_2016 = europe_2[europe_2['year'] == 2016]['genre'].value_counts()
europe_2017 = europe_2[europe_2['year'] == 2017]['genre'].value_counts()
europe_2018 = europe_2[europe_2['year'] == 2018]['genre'].value_counts()
europe_list = [europe_2006,europe_2007,europe_2008,europe_2009,europe_2010,europe_2011,europe_2012,europe_2013,europe_2014,europe_2015,europe_2016,europe_2017,europe_2018]

# %%
europe_c = pd.concat([( europe_2007- europe_2006)/ europe_2006,
                   (europe_2008-europe_2007)/europe_2007,
                   (europe_2009-europe_2008)/europe_2008,
                   (europe_2010-europe_2009)/europe_2009,
                   (europe_2011-europe_2010)/europe_2010,
                   (europe_2012-europe_2011)/europe_2011,
                   (europe_2013-europe_2012)/europe_2012,
                   (europe_2014-europe_2013)/europe_2013,
                   (europe_2015-europe_2014)/europe_2014,
                   (europe_2016-europe_2015)/europe_2015,
                   (europe_2017-europe_2016)/europe_2016,
                   (europe_2018-europe_2017)/europe_2017],axis=1,sort=False)
europe_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Action            0.100000  0.090909  0.000000  0.500000  0.111111  0.400000
# Adventure         0.000000 -0.250000  2.000000 -0.333333 -0.666667 -0.500000
# Fighting          0.333333 -0.750000  6.000000 -0.857143  1.000000       NaN
# Misc              0.625000  0.692308 -0.545455  0.100000  0.454545 -0.625000
# Platform          1.000000 -0.200000 -0.375000  0.600000 -0.250000 -0.333333
# Puzzle           -0.400000 -0.333333 -0.500000       NaN       NaN       NaN
# Racing           -0.214286 -0.363636  0.285714  0.111111  0.200000 -0.333333
# Role-Playing      0.250000  0.400000 -0.428571  1.250000 -0.333333  1.166667
# Shooter           1.000000 -0.312500  0.181818  0.076923  0.000000  0.571429
# Simulation        0.428571  0.100000 -0.363636 -0.428571 -0.250000  0.000000
# Sports            0.444444  0.153846  0.333333 -0.100000 -0.055556 -0.117647
# Strategy               NaN       NaN  2.000000 -0.666667  1.000000       NaN
# Action-Adventure       NaN       NaN       NaN       NaN       NaN       NaN
# Party                  NaN       NaN       NaN       NaN       NaN       NaN
# Music                  NaN       NaN       NaN       NaN       NaN       NaN
#
#                      genre     genre     genre     genre     genre     genre
# Action            0.214286 -0.029412 -0.303030 -0.130435 -0.250000  0.000000
# Adventure         3.000000  0.000000 -0.500000  0.500000 -0.333333 -0.500000
# Fighting               NaN  1.000000  1.000000 -0.250000  0.333333 -0.250000
# Misc             -0.500000  0.333333  1.000000  0.375000 -0.545455 -0.200000
# Platform          1.000000 -0.250000 -0.166667 -0.400000  0.666667  0.800000
# Puzzle                 NaN       NaN       NaN       NaN       NaN  0.000000
# Racing            0.250000 -0.200000  0.250000 -0.300000  0.428571 -0.200000
# Role-Playing     -0.461538  0.142857  0.500000  0.083333  0.307692 -0.235294
# Shooter           0.000000 -0.045455  0.047619 -0.136364  0.052632 -0.350000
# Simulation       -0.333333  1.000000  0.250000  0.200000 -0.666667  1.500000
# Sports           -0.533333  0.428571 -0.100000  0.666667 -0.200000 -0.083333
# Strategy               NaN       NaN       NaN       NaN       NaN  0.000000
# Action-Adventure       NaN       NaN       NaN       NaN       NaN  1.750000
# Party                  NaN       NaN       NaN       NaN       NaN  0.500000
# Music                  NaN       NaN       NaN       NaN       NaN       NaN

# %%
# Yearly Difference
print(np.diff(europe_list))
# Out:
# [Action          1.0
# Adventure       0.0
# Fighting        1.0
# Misc            5.0
# Platform        5.0
# Puzzle         -2.0
# Racing         -3.0
# Role-Playing    1.0
# Shooter         8.0
# Simulation      3.0
# Sports          4.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action          1.0
# Adventure      -1.0
# Fighting       -3.0
# Misc            9.0
# Platform       -2.0
# Puzzle         -1.0
# Racing         -4.0
# Role-Playing    2.0
# Shooter        -5.0
# Simulation      1.0
# Sports          2.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action           0
# Adventure        6
# Fighting         6
# Misc           -12
# Platform        -3
# Puzzle          -1
# Racing           2
# Role-Playing    -3
# Shooter          2
# Simulation      -4
# Sports           5
# Strategy         2
# Name: genre, dtype: int64
#  Action          6.0
# Adventure      -3.0
# Fighting       -6.0
# Misc            1.0
# Platform        3.0
# Puzzle          NaN
# Racing          1.0
# Role-Playing    5.0
# Shooter         1.0
# Simulation     -3.0
# Sports         -2.0
# Strategy       -2.0
# Name: genre, dtype: float64
#  Action          2
# Adventure      -4
# Fighting        1
# Misc            5
# Platform       -2
# Racing          2
# Role-Playing   -3
# Shooter         0
# Simulation     -1
# Sports         -1
# Strategy        1
# Name: genre, dtype: int64
#  Action           8.0
# Adventure       -1.0
# Fighting         NaN
# Misc           -10.0
# Platform        -2.0
# Racing          -4.0
# Role-Playing     7.0
# Shooter          8.0
# Simulation       0.0
# Sports          -2.0
# Strategy         NaN
# Name: genre, dtype: float64
#  Action          6.0
# Adventure       3.0
# Fighting        NaN
# Misc           -3.0
# Platform        4.0
# Puzzle          NaN
# Racing          2.0
# Role-Playing   -6.0
# Shooter         0.0
# Simulation     -1.0
# Sports         -8.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action         -1.0
# Adventure       0.0
# Fighting        1.0
# Misc            1.0
# Platform       -2.0
# Puzzle          NaN
# Racing         -2.0
# Role-Playing    1.0
# Shooter        -1.0
# Simulation      2.0
# Sports          3.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action         -10
# Adventure       -2
# Fighting         2
# Misc             4
# Platform        -1
# Racing           2
# Role-Playing     4
# Shooter          1
# Simulation       1
# Sports          -1
# Name: genre, dtype: int64
#  Action         -3
# Adventure       1
# Fighting       -1
# Misc            3
# Platform       -2
# Racing         -3
# Role-Playing    1
# Shooter        -3
# Simulation      1
# Sports          6
# Name: genre, dtype: int64
#  Action             -5.0
# Action-Adventure    NaN
# Adventure          -1.0
# Fighting            1.0
# Misc               -6.0
# Party               NaN
# Platform            2.0
# Puzzle              NaN
# Racing              3.0
# Role-Playing        4.0
# Shooter             1.0
# Simulation         -4.0
# Sports             -3.0
# Strategy            NaN
# Name: genre, dtype: float64
#  Action              0.0
# Action-Adventure    7.0
# Adventure          -1.0
# Fighting           -1.0
# Misc               -1.0
# Music               NaN
# Party               1.0
# Platform            4.0
# Puzzle              0.0
# Racing             -2.0
# Role-Playing       -4.0
# Shooter            -7.0
# Simulation          3.0
# Sports             -1.0
# Strategy            0.0
# Name: genre, dtype: float64]

# %%
# Yeary Percent Change
europe_c = pd.concat(europe_list,axis=1,sort=False).pct_change()
europe_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Racing                 NaN       NaN       NaN       NaN       NaN       NaN
# Action           -0.285714  0.000000  0.714286  0.333333  0.800000  0.666667
# Sports           -0.100000  0.181818  0.250000  0.666667  0.000000 -0.150000
# Shooter          -0.111111  0.230769 -0.266667 -0.350000 -0.222222 -0.176471
# Misc              0.000000 -0.187500  1.000000 -0.230769 -0.214286  0.142857
# Simulation       -0.125000 -0.230769 -0.500000 -0.300000 -0.636364 -0.812500
# Puzzle           -0.285714 -0.700000 -0.818182 -0.857143  0.000000  0.000000
# Platform          0.000000  2.333333  3.000000  4.000000  1.000000  1.000000
# Adventure        -0.200000 -0.600000 -0.625000  0.800000 -0.250000 -0.666667
# Role-Playing      0.000000  0.250000  1.333333 -0.555556  0.500000  2.000000
# Fighting         -0.250000 -0.200000 -0.857143  0.750000 -0.888889 -0.666667
# Strategy         -0.333333  0.000000  0.000000 -0.571429  0.000000  0.000000
# Action-Adventure  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Party             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Music             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                       genre     genre     genre     genre     genre     genre  \
# Racing                  NaN       NaN       NaN       NaN       NaN       NaN
# Action             2.500000  2.400000  3.125000  1.300000  1.857143  0.500000
# Sports            -0.464286 -0.794118 -0.696970 -0.608696 -0.250000 -0.200000
# Shooter            0.466667  2.142857  1.100000  1.444444  0.266667  0.666667
# Misc              -0.727273 -0.863636 -0.809524 -0.636364 -0.421053 -0.750000
# Simulation        -0.500000 -0.333333  0.000000 -0.375000 -0.454545 -0.600000
# Puzzle             0.000000 -0.500000  0.000000  0.000000  0.000000 -0.500000
# Platform           0.333333  7.000000  0.500000  0.000000 -0.500000  4.000000
# Adventure         -0.750000 -0.500000 -0.333333 -0.600000  0.000000 -0.600000
# Role-Playing      12.000000  0.750000  1.000000  5.000000  3.333333  7.500000
# Fighting           0.000000 -0.857143 -0.750000 -0.666667 -0.769231 -0.764706
# Strategy           0.000000  0.000000  0.000000  0.000000  0.000000 -0.750000
# Action-Adventure   0.000000  0.000000  0.000000  0.000000  0.000000  3.000000
# Party              0.000000  0.000000  0.000000  0.000000  0.000000 -0.500000
# Music              0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                       genre
# Racing                  NaN
# Action             0.875000
# Sports            -0.266667
# Shooter            0.181818
# Misc              -0.692308
# Simulation         0.250000
# Puzzle            -0.800000
# Platform           8.000000
# Adventure         -0.888889
# Role-Playing      12.000000
# Fighting          -0.769231
# Strategy          -0.666667
# Action-Adventure  10.000000
# Party             -0.727273
# Music             -0.333333

# %%
# Yearly difference in genre in top 100
np.diff(europe_list)
# Out:
# array([Action          1.0
# Adventure       0.0
# Fighting        1.0
# Misc            5.0
# Platform        5.0
# Puzzle         -2.0
# Racing         -3.0
# Role-Playing    1.0
# Shooter         8.0
# Simulation      3.0
# Sports          4.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action          1.0
# Adventure      -1.0
# Fighting       -3.0
# Misc            9.0
# Platform       -2.0
# Puzzle         -1.0
# Racing         -4.0
# Role-Playing    2.0
# Shooter        -5.0
# Simulation      1.0
# Sports          2.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action           0
# Adventure        6
# Fighting         6
# Misc           -12
# Platform        -3
# Puzzle          -1
# Racing           2
# Role-Playing    -3
# Shooter          2
# Simulation      -4
# Sports           5
# Strategy         2
# Name: genre, dtype: int64,
#        Action          6.0
# Adventure      -3.0
# Fighting       -6.0
# Misc            1.0
# Platform        3.0
# Puzzle          NaN
# Racing          1.0
# Role-Playing    5.0
# Shooter         1.0
# Simulation     -3.0
# Sports         -2.0
# Strategy       -2.0
# Name: genre, dtype: float64,
#        Action          2
# Adventure      -4
# Fighting        1
# Misc            5
# Platform       -2
# Racing          2
# Role-Playing   -3
# Shooter         0
# Simulation     -1
# Sports         -1
# Strategy        1
# Name: genre, dtype: int64,
#        Action           8.0
# Adventure       -1.0
# Fighting         NaN
# Misc           -10.0
# Platform        -2.0
# Racing          -4.0
# Role-Playing     7.0
# Shooter          8.0
# Simulation       0.0
# Sports          -2.0
# Strategy         NaN
# Name: genre, dtype: float64,
#        Action          6.0
# Adventure       3.0
# Fighting        NaN
# Misc           -3.0
# Platform        4.0
# Puzzle          NaN
# Racing          2.0
# Role-Playing   -6.0
# Shooter         0.0
# Simulation     -1.0
# Sports         -8.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action         -1.0
# Adventure       0.0
# Fighting        1.0
# Misc            1.0
# Platform       -2.0
# Puzzle          NaN
# Racing         -2.0
# Role-Playing    1.0
# Shooter        -1.0
# Simulation      2.0
# Sports          3.0
# Strategy        NaN
# Name: genre, dtype: float64,
#        Action         -10
# Adventure       -2
# Fighting         2
# Misc             4
# Platform        -1
# Racing           2
# Role-Playing     4
# Shooter          1
# Simulation       1
# Sports          -1
# Name: genre, dtype: int64,
#        Action         -3
# Adventure       1
# Fighting       -1
# Misc            3
# Platform       -2
# Racing         -3
# Role-Playing    1
# Shooter        -3
# Simulation      1
# Sports          6
# Name: genre, dtype: int64,
#        Action             -5.0
# Action-Adventure    NaN
# Adventure          -1.0
# Fighting            1.0
# Misc               -6.0
# Party               NaN
# Platform            2.0
# Puzzle              NaN
# Racing              3.0
# Role-Playing        4.0
# Shooter             1.0
# Simulation         -4.0
# Sports             -3.0
# Strategy            NaN
# Name: genre, dtype: float64,
#        Action              0.0
# Action-Adventure    7.0
# Adventure          -1.0
# Fighting           -1.0
# Misc               -1.0
# Music               NaN
# Party               1.0
# Platform            4.0
# Puzzle              0.0
# Racing             -2.0
# Role-Playing       -4.0
# Shooter            -7.0
# Simulation          3.0
# Sports             -1.0
# Strategy            0.0
# Name: genre, dtype: float64], dtype=object)

# %%
# Overall Console
value_counts_df(europe_2,'console')
# Out:
#          count
# console
#  (PS4)     249
#  (PS3)     207
#  (X360)    189
#  (Wii)     141
#  (DS)      127
#  (XOne)     92
#  (PC)       78
#  (3DS)      68
#  (PSP)      67
#  (NS)       35
#  (WiiU)     24
#  (PSV)       2

# %%
# Overall Genre
value_counts_df(europe_2, 'genre')
# Out:
#                   count
# genre
# Action              251
# Shooter             215
# Sports              171
# Racing              124
# Misc                121
# Role-Playing        118
# Platform             82
# Simulation           69
# Adventure            45
# Fighting             35
# Action-Adventure     15
# Puzzle               14
# Strategy             12
# Party                 5
# Music                 2

# %% [markdown]
# ## Japan Dataframe

# %%
japan_2_2006 = japan_2[japan_2['year'] == 2006]['genre'].value_counts()
japan_2_2007 = japan_2[japan_2['year'] == 2007]['genre'].value_counts()
japan_2_2008 = japan_2[japan_2['year'] == 2008]['genre'].value_counts()
japan_2_2009 = japan_2[japan_2['year'] == 2009]['genre'].value_counts()
japan_2_2010 = japan_2[japan_2['year'] == 2010]['genre'].value_counts()
japan_2_2011 = japan_2[japan_2['year'] == 2011]['genre'].value_counts()
japan_2_2012 = japan_2[japan_2['year'] == 2012]['genre'].value_counts()
japan_2_2013 = japan_2[japan_2['year'] == 2013]['genre'].value_counts()
japan_2_2014 = japan_2[japan_2['year'] == 2014]['genre'].value_counts()
japan_2_2015 = japan_2[japan_2['year'] == 2015]['genre'].value_counts()
japan_2_2016 = japan_2[japan_2['year'] == 2016]['genre'].value_counts()
japan_2_2017 = japan_2[japan_2['year'] == 2017]['genre'].value_counts()
japan_2_2018 = japan_2[japan_2['year'] == 2018]['genre'].value_counts()
japan_list = [japan_2_2006, japan_2_2007,japan_2_2008,japan_2_2009,japan_2_2010,japan_2_2011,japan_2_2012,japan_2_2013,japan_2_2014
,japan_2_2015,japan_2_2016,japan_2_2017,japan_2_2018]

# %%
japan_c = pd.concat([(japan_2_2007- japan_2_2006)/ japan_2_2006,
                   (japan_2_2008-japan_2_2007)/japan_2_2007,
                   (japan_2_2009-japan_2_2008)/japan_2_2008,
                   (japan_2_2010-japan_2_2009)/japan_2_2009,
                   (japan_2_2011-japan_2_2010)/japan_2_2010,
                   (japan_2_2012-japan_2_2011)/japan_2_2011,
                   (japan_2_2013-japan_2_2012)/japan_2_2012,
                   (japan_2_2014-japan_2_2013)/japan_2_2013,
                   (japan_2_2015-japan_2_2014)/japan_2_2014,
                   (japan_2_2016-japan_2_2015)/japan_2_2015,
                   (japan_2_2017-japan_2_2016)/japan_2_2016,
                   (japan_2_2018-japan_2_2017)/japan_2_2017],axis=1,sort=False)
japan_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Action            0.500000  0.000000  0.111111  0.200000  0.500000 -0.222222
# Adventure         0.833333 -0.363636  0.285714 -0.444444  0.800000 -0.555556
# Fighting         -0.250000  1.000000  0.166667 -0.571429  0.333333  0.000000
# Misc              0.166667 -0.095238 -0.473684  0.000000  0.100000  0.545455
# Platform          0.166667 -0.428571 -0.250000  1.000000  0.166667  0.000000
# Puzzle            0.000000       NaN       NaN -0.666667       NaN       NaN
# Racing            0.000000  2.000000  0.000000  0.000000  0.000000  0.000000
# Role-Playing     -0.393939  0.250000  0.160000  0.137931 -0.151515  0.000000
# Shooter          -0.500000  0.000000  0.000000  3.000000  0.000000 -0.250000
# Simulation       -0.166667  0.200000 -0.333333  0.500000 -0.666667  1.500000
# Sports           -0.083333  0.454545  0.062500 -0.235294 -0.076923 -0.250000
# Strategy          5.000000 -0.333333  0.000000  0.000000 -0.500000  2.000000
# Inc, Action            NaN       NaN       NaN       NaN       NaN       NaN
# Party                  NaN       NaN       NaN       NaN       NaN       NaN
# Action-Adventure       NaN       NaN       NaN       NaN       NaN       NaN
# Music                  NaN       NaN       NaN       NaN       NaN       NaN
#
#                      genre     genre     genre     genre     genre     genre
# Action            1.428571  0.352941  0.195652 -0.490909 -0.321429 -0.052632
# Adventure         0.000000 -0.500000  0.000000  1.500000 -0.200000  0.250000
# Fighting          0.000000 -0.250000  0.333333  0.000000  0.500000  0.500000
# Misc             -0.470588 -0.333333 -0.333333  1.250000 -0.333333 -0.166667
# Platform         -0.285714 -0.200000  0.000000 -0.250000  1.000000 -0.500000
# Puzzle                 NaN  0.000000       NaN       NaN  3.000000  0.000000
# Racing            0.000000 -0.333333  0.000000  0.000000  1.000000 -0.250000
# Role-Playing     -0.071429 -0.115385 -0.043478  0.136364  0.200000 -0.300000
# Shooter           0.333333 -0.250000  0.666667  0.200000  0.333333 -0.250000
# Simulation       -0.800000  1.000000       NaN       NaN -0.666667 -0.500000
# Sports           -0.333333  0.000000       NaN       NaN -0.285714  0.800000
# Strategy         -0.666667 -0.500000  0.000000  1.000000       NaN       NaN
# Inc, Action            NaN       NaN       NaN  0.000000       NaN       NaN
# Party                  NaN       NaN       NaN       NaN  1.000000  0.500000
# Action-Adventure       NaN       NaN       NaN       NaN       NaN  1.250000
# Music                  NaN       NaN       NaN       NaN       NaN       NaN

# %%
# Yearly Difference
print(np.diff(japan_list))
# Out:
# [Action           3
# Adventure        5
# Fighting        -1
# Misc             3
# Platform         1
# Puzzle           0
# Racing           0
# Role-Playing   -13
# Shooter         -1
# Simulation      -1
# Sports          -1
# Strategy         5
# Name: genre, dtype: int64
#  Action          0.0
# Adventure      -4.0
# Fighting        3.0
# Misc           -2.0
# Platform       -3.0
# Puzzle          NaN
# Racing          2.0
# Role-Playing    5.0
# Shooter         0.0
# Simulation      1.0
# Sports          5.0
# Strategy       -2.0
# Name: genre, dtype: float64
#  Action          1.0
# Adventure       2.0
# Fighting        1.0
# Misc           -9.0
# Platform       -1.0
# Puzzle          NaN
# Racing          0.0
# Role-Playing    4.0
# Shooter         0.0
# Simulation     -2.0
# Sports          1.0
# Strategy        0.0
# Name: genre, dtype: float64
#  Action          2
# Adventure      -4
# Fighting       -4
# Misc            0
# Platform        3
# Puzzle         -2
# Racing          0
# Role-Playing    4
# Shooter         3
# Simulation      2
# Sports         -4
# Strategy        0
# Name: genre, dtype: int64
#  Action          6.0
# Adventure       4.0
# Fighting        1.0
# Misc            1.0
# Platform        1.0
# Puzzle          NaN
# Racing          0.0
# Role-Playing   -5.0
# Shooter         0.0
# Simulation     -4.0
# Sports         -1.0
# Strategy       -2.0
# Name: genre, dtype: float64
#  Action         -4
# Adventure      -5
# Fighting        0
# Misc            6
# Platform        0
# Racing          0
# Role-Playing    0
# Shooter        -1
# Simulation      3
# Sports         -3
# Strategy        4
# Name: genre, dtype: int64
#  Action          20.0
# Adventure        0.0
# Fighting         0.0
# Misc            -8.0
# Platform        -2.0
# Puzzle           NaN
# Racing           0.0
# Role-Playing    -2.0
# Shooter          1.0
# Simulation      -4.0
# Sports          -3.0
# Strategy        -4.0
# Name: genre, dtype: float64
#  Action          12
# Adventure       -2
# Fighting        -1
# Misc            -3
# Platform        -1
# Puzzle           0
# Racing          -1
# Role-Playing    -3
# Shooter         -1
# Simulation       1
# Sports           0
# Strategy        -1
# Name: genre, dtype: int64
#  Action          9.0
# Adventure       0.0
# Fighting        1.0
# Inc, Action     NaN
# Misc           -2.0
# Platform        0.0
# Puzzle          NaN
# Racing          0.0
# Role-Playing   -1.0
# Shooter         2.0
# Simulation      NaN
# Sports          NaN
# Strategy        0.0
# Name: genre, dtype: float64
#  Action         -27.0
# Adventure        3.0
# Fighting         0.0
# Inc, Action      0.0
# Misc             5.0
# Party            NaN
# Platform        -1.0
# Puzzle           NaN
# Racing           0.0
# Role-Playing     3.0
# Shooter          1.0
# Simulation       NaN
# Sports           NaN
# Strategy         1.0
# Name: genre, dtype: float64
#  Action             -9.0
# Action-Adventure    NaN
# Adventure          -1.0
# Fighting            2.0
# Inc, Action         NaN
# Misc               -3.0
# Party               1.0
# Platform            3.0
# Puzzle              3.0
# Racing              2.0
# Role-Playing        5.0
# Shooter             2.0
# Simulation         -4.0
# Sports             -2.0
# Strategy            NaN
# Name: genre, dtype: float64
#  Action             -1.0
# Action-Adventure    5.0
# Adventure           1.0
# Fighting            3.0
# Misc               -1.0
# Music               NaN
# Party               1.0
# Platform           -3.0
# Puzzle              0.0
# Racing             -1.0
# Role-Playing       -9.0
# Shooter            -2.0
# Simulation         -1.0
# Sports              4.0
# Strategy            NaN
# Name: genre, dtype: float64]

# %%
japan_c = pd.concat(japan_list,axis=1,sort=False).pct_change()
japan_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Role-Playing           NaN       NaN       NaN       NaN       NaN       NaN
# Misc             -0.454545  0.050000 -0.240000 -0.655172 -0.696970 -0.607143
# Sports           -0.333333 -0.476190 -0.157895  0.700000  0.300000  0.090909
# Simulation       -0.500000 -0.545455 -0.625000 -0.764706 -0.538462 -0.833333
# Action            0.000000  0.800000  0.500000  1.500000  1.000000  8.000000
# Adventure         0.000000  0.222222 -0.222222 -0.100000 -0.583333 -0.500000
# Platform          0.000000 -0.363636 -0.428571 -0.666667  0.200000 -0.222222
# Puzzle           -0.166667 -0.285714  0.000000  0.000000 -0.833333  0.000000
# Fighting         -0.200000 -0.400000  0.500000  1.333333  2.000000 -0.428571
# Shooter          -0.500000 -0.666667 -0.833333 -0.857143  0.333333  0.000000
# Racing           -0.500000  0.000000  2.000000  2.000000 -0.250000 -0.250000
# Strategy          0.000000  5.000000  0.333333  0.333333  0.333333 -0.333333
# Inc, Action       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Party             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Action-Adventure  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Music             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                      genre      genre      genre      genre     genre  \
# Role-Playing           NaN        NaN        NaN        NaN       NaN
# Misc             -0.392857  -0.653846  -0.739130  -0.818182 -0.640000
# Sports           -0.470588  -0.333333   0.000000   0.000000 -0.222222
# Simulation       -0.444444  -0.833333  -0.666667   0.000000 -0.142857
# Action            1.800000  33.000000  22.000000  12.750000  3.666667
# Adventure        -0.714286  -0.882353  -0.956522  -0.963636 -0.821429
# Platform          0.750000   0.250000   1.000000   1.000000 -0.400000
# Puzzle            0.000000  -0.600000  -0.500000   0.000000 -0.666667
# Fighting         -0.428571   1.000000   0.500000   0.000000  3.000000
# Shooter          -0.250000   0.000000   0.000000   0.250000  0.500000
# Racing            0.000000  -0.250000  -0.333333  -0.600000 -0.666667
# Strategy          1.000000  -0.333333  -0.500000  -0.500000  0.000000
# Inc, Action       0.000000   0.000000   0.000000   0.000000 -0.500000
# Party             0.000000   0.000000   0.000000   0.000000  0.000000
# Action-Adventure  0.000000   0.000000   0.000000   0.000000  0.000000
# Music             0.000000   0.000000   0.000000   0.000000  0.000000
#
#                      genre      genre
# Role-Playing           NaN        NaN
# Misc             -0.800000  -0.761905
# Sports           -0.166667   0.800000
# Simulation       -0.600000  -0.888889
# Action            8.500000  17.000000
# Adventure        -0.789474  -0.722222
# Platform          0.500000  -0.400000
# Puzzle           -0.333333   0.333333
# Fighting          0.500000   1.250000
# Shooter           0.333333  -0.333333
# Racing           -0.500000  -0.500000
# Strategy          0.000000   0.000000
# Inc, Action       0.000000   0.000000
# Party            -0.500000   0.000000
# Action-Adventure  1.000000   2.000000
# Music             0.000000  -0.888889

# %%
# Overall Console
value_counts_df(japan_2,'console')
# Out:
#          count
# console
#  (3DS)     241
#  (DS)      230
#  (PS3)     186
#  (PS4)     152
#  (PSP)     134
#  (Wii)     110
#  (PS2)      74
#  (PSV)      64
#  (NS)       56
#  (WiiU)     42
#  (GBA)       7
#  (X360)      3
#  (GC)        1

# %%
# Overall Genre
value_counts_df(japan_2, 'genre')
# Out:
#                   count
# genre
# Role-Playing        343
# Action              278
# Misc                145
# Sports              123
# Adventure            73
# Platform             65
# Fighting             61
# Shooter              48
# Simulation           46
# Strategy             36
# Racing               33
# Puzzle               27
# Action-Adventure     13
# Party                 6
# Inc, Action           2
# Music                 1

# %% [markdown]
# ## Global

# %%
global_2006 = global_2[global_2['year'] == 2006]['genre'].value_counts()
global_2007 = global_2[global_2['year'] == 2007]['genre'].value_counts()
global_2008 = global_2[global_2['year'] == 2008]['genre'].value_counts()
global_2009 = global_2[global_2['year'] == 2009]['genre'].value_counts()
global_2010 = global_2[global_2['year'] == 2010]['genre'].value_counts()
global_2011 = global_2[global_2['year'] == 2011]['genre'].value_counts()
global_2012 = global_2[global_2['year'] == 2012]['genre'].value_counts()
global_2013 = global_2[global_2['year'] == 2013]['genre'].value_counts()
global_2014 = global_2[global_2['year'] == 2014]['genre'].value_counts()
global_2015 = global_2[global_2['year'] == 2015]['genre'].value_counts()
global_2016 = global_2[global_2['year'] == 2016]['genre'].value_counts()
global_2017 = global_2[global_2['year'] == 2017]['genre'].value_counts()
global_2018 = global_2[global_2['year'] == 2018]['genre'].value_counts()
global_list = [global_2006,global_2007,global_2008,global_2009,global_2010,global_2011,global_2012,global_2013,global_2014,global_2015,global_2016,global_2017,global_2018]

# %%
global_c = pd.concat([(global_2007- global_2006)/ global_2006,
                   (global_2008-global_2007)/global_2_2007,
                   (global_2009-global_2008)/global_2_2008,
                   (global_2010-global_2009)/global_2_2009,
                   (global_2011-global_2010)/global_2_2010,
                   (global_2012-global_2011)/global_2_2011,
                   (global_2013-global_2012)/global_2_2012,
                   (global_2014-global_2013)/global_2_2013,
                   (global_2015-global_2014)/global_2_2014,
                   (global_2016-global_2015)/global_2_2015,
                   (global_2017-global_2016)/global_2_2016,
                   (global_2018-global_2017)/global_2_2017],axis=1,sort=False)
global_c
# Out:
#                      genre     genre     genre     genre     genre     genre  \
# Action           -0.222222  1.142857 -0.133333  0.153846  0.266667  0.526316
# Adventure         1.000000  0.166667  0.000000 -0.142857 -0.500000 -0.666667
# Fighting         -0.500000 -0.333333  3.500000 -0.777778  0.500000       NaN
# Misc              0.250000  0.466667 -0.636364  0.500000  0.000000 -0.500000
# Platform          0.571429 -0.181818 -0.444444  0.800000 -0.222222 -0.428571
# Puzzle           -0.500000       NaN       NaN  0.000000  0.000000       NaN
# Racing            0.000000 -0.625000  1.333333  0.142857 -0.250000  0.166667
# Role-Playing      0.166667 -0.285714  0.400000  0.142857 -0.500000  0.750000
# Shooter           0.071429 -0.133333  0.076923  0.000000  0.500000 -0.142857
# Simulation        0.000000  0.000000 -0.500000       NaN       NaN  0.500000
# Sports           -0.214286  0.000000  0.545455 -0.058824  0.125000 -0.055556
# Strategy               NaN       NaN       NaN  0.000000       NaN       NaN
# Action-Adventure       NaN       NaN       NaN       NaN       NaN       NaN
# Party                  NaN       NaN       NaN       NaN       NaN       NaN
# Music                  NaN       NaN       NaN       NaN       NaN       NaN
# Sandbox                NaN       NaN       NaN       NaN       NaN       NaN
#
#                      genre     genre     genre     genre     genre     genre
# Action            0.172414  0.058824 -0.250000 -0.148148 -0.173913 -0.105263
# Adventure         3.000000  0.250000 -0.600000  0.500000 -0.666667  0.000000
# Fighting               NaN  0.000000  1.500000 -0.400000  0.666667  0.000000
# Misc             -0.333333 -0.750000  6.000000  0.714286 -0.666667  0.000000
# Platform          1.000000 -0.125000 -0.428571 -0.250000  0.333333  1.250000
# Puzzle                 NaN       NaN       NaN       NaN       NaN  0.000000
# Racing           -0.142857  0.000000 -0.166667 -0.200000  0.500000  0.000000
# Role-Playing     -0.285714  0.100000  0.090909  0.166667  0.428571 -0.400000
# Shooter           0.000000 -0.055556  0.294118 -0.045455  0.047619 -0.409091
# Simulation       -0.333333 -0.500000  3.000000  0.000000 -0.500000  0.000000
# Sports           -0.411765  0.400000 -0.142857  0.083333 -0.076923  0.083333
# Strategy          0.000000       NaN       NaN       NaN       NaN  0.000000
# Action-Adventure       NaN       NaN       NaN       NaN       NaN  5.000000
# Party                  NaN       NaN       NaN       NaN       NaN  1.000000
# Music                  NaN       NaN       NaN       NaN       NaN       NaN
# Sandbox                NaN       NaN       NaN       NaN       NaN       NaN

# %%
print(np.diff(global_list))
# Out:
# [Action         -2.0
# Adventure       3.0
# Fighting       -3.0
# Misc            3.0
# Platform        4.0
# Puzzle         -2.0
# Racing          0.0
# Role-Playing    2.0
# Shooter         1.0
# Simulation      0.0
# Sports         -3.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action          8.0
# Adventure       1.0
# Fighting       -1.0
# Misc            7.0
# Platform       -2.0
# Puzzle          NaN
# Racing         -5.0
# Role-Playing   -4.0
# Shooter        -2.0
# Simulation      0.0
# Sports          0.0
# Name: genre, dtype: float64
#  Action          -2.0
# Adventure        0.0
# Fighting         7.0
# Misc           -14.0
# Platform        -4.0
# Puzzle           NaN
# Racing           4.0
# Role-Playing     4.0
# Shooter          1.0
# Simulation      -4.0
# Sports           6.0
# Strategy         NaN
# Name: genre, dtype: float64
#  Action          2.0
# Adventure      -1.0
# Fighting       -7.0
# Misc            4.0
# Platform        4.0
# Puzzle          0.0
# Racing          1.0
# Role-Playing    2.0
# Shooter         0.0
# Simulation      NaN
# Sports         -1.0
# Strategy        0.0
# Name: genre, dtype: float64
#  Action          4.0
# Adventure      -3.0
# Fighting        1.0
# Misc            0.0
# Platform       -2.0
# Puzzle          0.0
# Racing         -2.0
# Role-Playing   -8.0
# Shooter         7.0
# Simulation      NaN
# Sports          2.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action          10.0
# Adventure       -2.0
# Fighting         NaN
# Misc            -6.0
# Platform        -3.0
# Puzzle           NaN
# Racing           1.0
# Role-Playing     6.0
# Shooter         -3.0
# Simulation       1.0
# Sports          -1.0
# Strategy         NaN
# Name: genre, dtype: float64
#  Action          5.0
# Adventure       3.0
# Fighting        NaN
# Misc           -2.0
# Platform        4.0
# Puzzle          NaN
# Racing         -1.0
# Role-Playing   -4.0
# Shooter         0.0
# Simulation     -1.0
# Sports         -7.0
# Strategy        0.0
# Name: genre, dtype: float64
#  Action          2.0
# Adventure       1.0
# Fighting        0.0
# Misc           -3.0
# Platform       -1.0
# Puzzle          NaN
# Racing          0.0
# Role-Playing    1.0
# Shooter        -1.0
# Simulation     -1.0
# Sports          4.0
# Strategy        NaN
# Name: genre, dtype: float64
#  Action         -9
# Adventure      -3
# Fighting        3
# Misc            6
# Platform       -3
# Racing         -1
# Role-Playing    1
# Shooter         5
# Simulation      3
# Sports         -2
# Name: genre, dtype: int64
#  Action         -4
# Adventure       1
# Fighting       -2
# Misc            5
# Platform       -1
# Racing         -1
# Role-Playing    2
# Shooter        -1
# Simulation      0
# Sports          1
# Name: genre, dtype: int64
#  Action             -4.0
# Action-Adventure    NaN
# Adventure          -2.0
# Fighting            2.0
# Misc               -8.0
# Party               NaN
# Platform            1.0
# Puzzle              NaN
# Racing              2.0
# Role-Playing        6.0
# Shooter             1.0
# Simulation         -2.0
# Sports             -1.0
# Strategy            NaN
# Name: genre, dtype: float64
#  Action              -2.0
# Action-Adventure    10.0
# Adventure            0.0
# Fighting             0.0
# Misc                 0.0
# Music                NaN
# Party                1.0
# Platform             5.0
# Puzzle               0.0
# Racing               0.0
# Role-Playing        -8.0
# Sandbox              NaN
# Shooter             -9.0
# Simulation           0.0
# Sports               1.0
# Strategy             0.0
# Name: genre, dtype: float64]

# %%
# Overall
value_counts_df(global_2, 'genre')
# Out:
#                   count
# genre
# Action              263
# Shooter             222
# Sports              178
# Role-Playing        167
# Misc                119
# Platform             87
# Racing               80
# Adventure            49
# Simulation           48
# Fighting             47
# Action-Adventure     14
# Puzzle               12
# Strategy              9
# Party                 3
# Sandbox               1
# Music                 1

# %% [markdown]
# # Overall

# %%
global_console = value_counts_df(global_2, 'console')
usa_console = value_counts_df(usa_2, 'console')
europe_console = value_counts_df(europe_2, 'console')
japan_console = value_counts_df(japan_2, 'console')

# %%
console_total = pd.concat([global_console,usa_console,europe_console,japan_console],axis=1,sort=True)
console_total.columns = ['Global', 'USA','Europe', 'Japan']
console_total
# Out:
#          Global    USA  Europe  Japan
#  (3DS)     88.0   62.0    68.0  241.0
#  (DS)     159.0  130.0   127.0  230.0
#  (GBA)      NaN    NaN     NaN    7.0
#  (GC)       NaN    NaN     NaN    1.0
#  (NS)      38.0   41.0    35.0   56.0
#  (PC)      30.0   14.0    78.0    NaN
#  (PS2)      NaN    NaN     NaN   74.0
#  (PS3)    204.0  171.0   207.0  186.0
#  (PS4)    217.0  188.0   249.0  152.0
#  (PSP)     54.0   35.0    67.0  134.0
#  (PSV)      2.0    NaN     2.0   64.0
#  (Wii)    133.0  163.0   141.0  110.0
#  (WiiU)    30.0   28.0    24.0   42.0
#  (X360)   232.0  312.0   189.0    3.0
#  (XOne)   113.0  156.0    92.0    NaN

# %%
global_freq = value_counts_df(global_2, 'genre')
usa_freq = value_counts_df(usa_2, 'genre')
europe_freq = value_counts_df(europe_2, 'genre')
japan_freq = value_counts_df(japan_2, 'genre')

# %%
genre_freq = pd.concat([global_freq,usa_freq,europe_freq,japan_freq],axis=1,sort=True)
genre_freq.columns = ['Global', 'USA','Europe', 'Japan']
genre_freq
# Out:
#                   Global    USA  Europe  Japan
# Action             263.0  272.0   251.0  278.0
# Action-Adventure    14.0   14.0    15.0   13.0
# Adventure           49.0   43.0    45.0   73.0
# Fighting            47.0   51.0    35.0   61.0
# Inc, Action          NaN    NaN     NaN    2.0
# Misc               119.0  107.0   121.0  145.0
# Music                1.0    2.0     2.0    1.0
# Party                3.0    3.0     5.0    6.0
# Platform            87.0   89.0    82.0   65.0
# Puzzle              12.0   12.0    14.0   27.0
# Racing              80.0   71.0   124.0   33.0
# Role-Playing       167.0  132.0   118.0  343.0
# Sandbox              1.0    NaN     NaN    NaN
# Shooter            222.0  243.0   215.0   48.0
# Simulation          48.0   35.0    69.0   46.0
# Sports             178.0  217.0   171.0  123.0
# Strategy             9.0    9.0    12.0   36.0

# %%
two_tho_six = global_2[global_2['year'] == 2006]
two_tho_six.groupby(['rank'])
two_tho_six.drop_duplicates()
# Out:
#     rank                                         video_game  year  console  \
# 0      1                              New Super Mario Bros.  2006     (DS)
# 1      2                                         Nintendogs  2006     (DS)
# 2      3       Brain Age: Train Your Brain in Minutes a Day  2006     (DS)
# 3      4                        Animal Crossing: Wild World  2006     (DS)
# 4      5                    Pokemon Diamond / Pearl Version  2006     (DS)
# 5      6        Brain Age 2: More Training in Minutes a Day  2006     (DS)
# 6      7                                      Mario Kart DS  2006     (DS)
# 7      8                                       Gears of War  2006   (X360)
# 8      9                                         Wii Sports  2006    (Wii)
# 9     10                                  Big Brain Academy  2006     (DS)
# 10    11             The Legend of Zelda: Twilight Princess  2006    (Wii)
# 11    12  English Training: Have Fun Improving Your Skills!  2006     (DS)
# 12    13             Grand Theft Auto: Liberty City Stories  2006    (PSP)
# 13    14                                      Madden NFL 07  2006   (X360)
# 14    15                                          Tetris DS  2006     (DS)
# 15    16                                  Final Fantasy III  2006     (DS)
# 16    17                     The Elder Scrolls IV: Oblivion  2006   (X360)
# 17    18                                     Call of Duty 3  2006   (X360)
# 18    19                                     Pokemon Ranger  2006     (DS)
# 19    20                                  Super Mario 64 DS  2006     (DS)
# 20    21       Tom Clancy's Ghost Recon Advanced Warfighter  2006   (X360)
# 21    22                                         Saints Row  2006   (X360)
# 22    23                                        Dead Rising  2006   (X360)
# 23    24                                 Kirby Squeak Squad  2006     (DS)
# 24    25  Kanshuu Nippon Joushikiryoku Kentei Kyoukai: I...  2006     (DS)
# 25    26                                 Mario Hoops 3 on 3  2006     (DS)
# 26    27                                         Sonic Rush  2006     (DS)
# 27    28          Pokemon Mystery Dungeon: Blue Rescue Team  2006     (DS)
# 28    29                Grand Theft Auto: Vice City Stories  2006    (PSP)
# 29    30          Oshare Majo Love and Berry: DS Collection  2006     (DS)
# ..   ...                                                ...   ...      ...
# 70    71                                    Gangs of London  2006    (PSP)
# 71         43       359434      359434                        Atari
# 72         30       357617      357617                          THQ
# 73         15       357573      357573                          THQ
# 74          4       354933      354933                       Konami
# 75         10       344307      344307                   Activision
# 76         64       343834      491250                          THQ
# 77         14       335838      335838               Rocket Company
# 78        109       326300     1999333                     Nintendo
# 79          5       321092      720237                      Unknown
# 80         44       314378      314378  Sony Computer Entertainment
# 81          7       308561      308561                         Sega
# 82         30       308381      308381                          THQ
# 83         62       304460      426912              Electronic Arts
# 84         11       296809      296809              Electronic Arts
# 85         38       294857      294857                        Spike
# 86         14       293298      293298         Take-Two Interactive
# 87         40       292717      292717              Electronic Arts
# 88          6       289942      289942                      Ubisoft
# 89          8       288772      288772                   Activision
# 90         44       286909      286909                  Square Enix
# 91         53       284386      364859                        Tecmo
# 92          8       282072      282072                          THQ
# 93         43       279672      279672                          THQ
# 94         22       270787      270787                 Namco Bandai
# 95         59       268637      501300              Electronic Arts
# 96         14       267480      267480              Electronic Arts
# 97         71       265654      489235                 Namco Bandai
# 98          5       262414      720237                   Activision
# 99         41       259806      259806                    505 Games
#
#            genre
# 0       Platform
# 1     Simulation
# 2           Misc
# 3     Simulation
# 4   Role-Playing
# 5           Misc
# 6         Racing
# 7        Shooter
# 8         Sports
# 9           Misc
# 10     Adventure
# 11          Misc
# 12        Action
# 13        Sports
# 14        Puzzle
# 15  Role-Playing
# 16  Role-Playing
# 17       Shooter
# 18  Role-Playing
# 19      Platform
# 20       Shooter
# 21        Action
# 22        Action
# 23      Platform
# 24          Misc
# 25        Sports
# 26      Platform
# 27  Role-Playing
# 28        Action
# 29          Misc
# ..           ...
# 70     Adventure
# 71      Fighting
# 72        Racing
# 73     Adventure
# 74        Action
# 75  Role-Playing
# 76      Strategy
# 77          Misc
# 78        Puzzle
# 79      Strategy
# 80        Sports
# 81          Misc
# 82        Racing
# 83    Simulation
# 84       Shooter
# 85        Sports
# 86        Sports
# 87       Shooter
# 88       Shooter
# 89        Sports
# 90  Role-Playing
# 91      Fighting
# 92      Fighting
# 93        Action
# 94      Strategy
# 95        Racing
# 96        Sports
# 97          Misc
# 98       Shooter
# 99    Simulation
#
# [100 rows x 9 columns]

# %%
two_tho_sev = global_2[global_2['year'] == 2007]
two_tho_sev
# Out:
#       rank                                         video_game  year  console  \
# 216      1                                         Wii Sports  2007    (Wii)
# 230      2                    Pokemon Diamond / Pearl Version  2007     (DS)
# 244      3                                           Wii Play  2007    (Wii)
# 262      4                                             Halo 3  2007   (X360)
# 263      5                                         Nintendogs  2007     (DS)
# 281      6        Brain Age 2: More Training in Minutes a Day  2007     (DS)
# 300      7       Brain Age: Train Your Brain in Minutes a Day  2007     (DS)
# 301      8                              New Super Mario Bros.  2007     (DS)
# 320      9                                 Super Mario Galaxy  2007    (Wii)
# 341     10                                      Mario Party 8  2007    (Wii)
# 342     11                     Call of Duty 4: Modern Warfare  2007   (X360)
# 361     12             The Legend of Zelda: Phantom Hourglass  2007     (DS)
# 362     13                                      Mario Kart DS  2007     (DS)
# 381     14                                 Forza Motorsport 2  2007   (X360)
# 89          8       288772      288772                   Activision
# 90         44       286909      286909                  Square Enix
# 91         53       284386      364859                        Tecmo
# 92          8       282072      282072                          THQ
# 93         43       279672      279672                          THQ
# 94         22       270787      270787                 Namco Bandai
# 95         59       268637      501300              Electronic Arts
# 96         14       267480      267480              Electronic Arts
# 97         71       265654      489235                 Namco Bandai
# 98          5       262414      720237                   Activision
# 99         41       259806      259806                    505 Games
#
#            genre
# 0       Platform
# 1     Simulation
# 2           Misc
# 3     Simulation
# 4   Role-Playing
# 5           Misc
# 6         Racing
# 7        Shooter
# 8         Sports
# 9           Misc
# 10     Adventure
# 11          Misc
# 12        Action
# 13        Sports
# 14        Puzzle
# 15  Role-Playing
# 16  Role-Playing
# 17       Shooter
# 18  Role-Playing
# 19      Platform
# 20       Shooter
# 21        Action
# 22        Action
# 23      Platform
# 24          Misc
# 25        Sports
# 26      Platform
# 27  Role-Playing
# 28        Action
# 29          Misc
# ..           ...
# 70     Adventure
# 71      Fighting
# 72        Racing
# 73     Adventure
# 74        Action
# 75  Role-Playing
# 76      Strategy
# 77          Misc
# 78        Puzzle
# 79      Strategy
# 80        Sports
# 81          Misc
# 82        Racing
# 83    Simulation
# 84       Shooter
# 85        Sports
# 86        Sports
# 87       Shooter
# 88       Shooter
# 89        Sports
# 90  Role-Playing
# 91      Fighting
# 92      Fighting
# 93        Action
# 94      Strategy
# 95        Racing
# 96        Sports
# 97          Misc
# 98       Shooter
# 99    Simulation
#
# [100 rows x 9 columns]

# %%
for i in range(2006,2019):
    print(i,'\n\n',pd.DataFrame(global_2[global_2['year'] == i]['genre'].value_counts()),'\n')
# Out:
# 2006
#
#                genre
# Sports           14
# Shooter          14
# Role-Playing     12
# Misc             12
# Action            9
# Racing            8
# Simulation        8
# Platform          7
# Fighting          6
# Puzzle            4
# Strategy          3
# Adventure         3
#
# 2007
#
#                genre
# Shooter          15
# Misc             15
# Role-Playing     14
# Sports           11
# Platform         11
# Simulation        8
# Racing            8
# Action            7
# Adventure         6
# Fighting          3
# Puzzle            2
#
# 2008
#
#                genre
# Misc             22
# Action           15
# Shooter          13
# Sports           11
# Role-Playing     10
# Platform          9
# Simulation        8
# Adventure         7
# Racing            3
# Fighting          2
#
# 2009
#
#                genre
# Sports           17
# Shooter          14
# Role-Playing     14
# Action           13
# Fighting          9
# Misc              8
# Adventure         7
# Racing            7
# Platform          5
# Simulation        4
# Puzzle            1
# Strategy          1
#
# 2010
#
#                genre
# Sports           16
# Role-Playing     16
# Action           15
# Shooter          14
# Misc             12
# Platform          9
# Racing            8
# Adventure         6
# Fighting          2
# Puzzle            1
# Strategy          1
#
# 2011
#
#                genre
# Shooter          21
# Action           19
# Sports           18
# Misc             12
# Role-Playing      8
# Platform          7
# Racing            6
# Fighting          3
# Adventure         3
# Simulation        2
# Puzzle            1
#
# 2012
#
#                genre
# Action           29
# Shooter          18
# Sports           17
# Role-Playing     14
# Racing            7
# Misc              6
# Platform          4
# Simulation        3
# Strategy          1
# Adventure         1
#
# 2013
#
#                genre
# Action           34
# Shooter          18
# Sports           10
# Role-Playing     10
# Platform          8
# Racing            6
# Adventure         4
# Misc              4
# Simulation        2
# Fighting          2
# Puzzle            1
# Strategy          1
#
# 2014
#
#                genre
# Action           36
# Shooter          17
# Sports           14
# Role-Playing     11
# Platform          7
# Racing            6
# Adventure         5
# Fighting          2
# Simulation        1
# Misc              1
#
# 2015
#
#                genre
# Action           27
# Shooter          22
# Sports           12
# Role-Playing     12
# Misc              7
# Racing            5
# Fighting          5
# Simulation        4
# Platform          4
# Adventure         2
#
# 2016
#
#                genre
# Action           23
# Shooter          21
# Role-Playing     14
# Sports           13
# Misc             12
# Simulation        4
# Racing            4
# Adventure         3
# Fighting          3
# Platform          3
#
# 2017
#
#                    genre
# Shooter              22
# Role-Playing         20
# Action               19
# Sports               12
# Racing                6
# Fighting              5
# Misc                  4
# Platform              4
# Action-Adventure      2
# Simulation            2
# Puzzle                1
# Strategy              1
# Adventure             1
# Party                 1
#
# 2018
#
#                    genre
# Action               17
# Shooter              13
# Sports               13
# Role-Playing         12
# Action-Adventure     12
# Platform              9
# Racing                6
# Fighting              5
# Misc                  4
# Simulation            2
# Party                 2
# Puzzle                1
# Strategy              1
# Adventure             1
# Music                 1
# Sandbox               1

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(pd.DataFrame(global_2[global_2['year'] == 2006]['genre'].value_counts()))
# Out:
# C:\Users\mikel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# ([<matplotlib.patches.Wedge at 0x2269e68fa90>,
#   <matplotlib.patches.Wedge at 0x2269da71e48>,
#   <matplotlib.patches.Wedge at 0x2269d374e80>,
#   <matplotlib.patches.Wedge at 0x2269d50d390>,
#   <matplotlib.patches.Wedge at 0x2269e707390>,
#   <matplotlib.patches.Wedge at 0x2269e707780>,
#   <matplotlib.patches.Wedge at 0x2269e707b38>,
#   <matplotlib.patches.Wedge at 0x2269c3f2630>,
#   <matplotlib.patches.Wedge at 0x2269da2d160>,
#   <matplotlib.patches.Wedge at 0x2269e1ba898>,
#   <matplotlib.patches.Wedge at 0x2269d9f7a58>,
#   <matplotlib.patches.Wedge at 0x2269e6fc048>],
#  [Text(0.9953097568356063, 0.4683572225853324, ''),
#   Text(0.2735588698961106, 1.0654414787782402, ''),
#   Text(-0.5894094736073276, 0.9287607186040616, ''),
#   Text(-1.0654414723751322, 0.2735588948345682, ''),
#   Text(-1.009530094796705, -0.436862664575214, ''),
#   Text(-0.646563785853741, -0.889918687758875, ''),
#   Text(-0.1378665793997472, -1.0913261686061657, ''),
#   Text(0.3726116861066107, -1.0349688552689829, ''),
#   Text(0.7530017936233573, -0.8018655116663935, ''),
#   Text(0.9639373291943449, -0.5299290758070114, ''),
#   Text(1.0563230418175553, -0.3068902594174461, ''),
#   Text(1.0951181564353798, -0.1035191936095687, '')])

# %%
df_2.sort_values(by=['year','genre','total_sale'])[:300]
# 5262          9       159646      159646                Vivendi Games
# 1425         25       165620      165620         Take-Two Interactive
# 5184         25       165620      165620         Take-Two Interactive
# 690           8       198658      198658  Sony Computer Entertainment
# 4740          8       198658      198658  Sony Computer Entertainment
# 434          18       221444      221444                     Nintendo
# 4572         18       221444      221444                     Nintendo
# 370           6       225786      225786                      Ubisoft
#
#              genre
# 1170        Action
# 5045        Action
# 882         Action
# 4866        Action
# 722         Action
# 4761        Action
# 562         Action
# 4656        Action
# 498         Action
# 4614        Action
# 164         Action
# 4362        Action
# 2977        Action
# 3098        Action
# 4747        Action
# 43          Action
# 4068        Action
# 2417        Action
# 2586        Action
# 4348        Action
# 2231        Action
# 2400        Action
# 4222        Action
# 24          Action
# 3880        Action
# 20          Action
# 3796        Action
# 1733        Action
# 1904        Action
# 3887        Action
# ...            ...
# 3363  Role-Playing
# 1158  Role-Playing
# 1332  Role-Playing
# 3510  Role-Playing
# 1413  Role-Playing
# 1588  Role-Playing
# 3677  Role-Playing
# 646   Role-Playing
# 821   Role-Playing
# 3253  Role-Playing
# 582   Role-Playing
# 757   Role-Playing
# 3240  Role-Playing
# 550   Role-Playing
# 725   Role-Playing
# 3235  Role-Playing
# 211   Role-Playing
# 373   Role-Playing
# 3204  Role-Playing
# 1713       Shooter
# 5289       Shooter
# 1617       Shooter
# 5262       Shooter
# 1425       Shooter
# 5184       Shooter
# 690        Shooter
# 4740       Shooter
# 434        Shooter
# 4572       Shooter
# 370        Shooter
#
# [300 rows x 9 columns]

# %%
df_5.sort_values(by=['year']).sort_values(by=['rank'])
# Out:
#       rank                               video_game  \
# 0        1                             [Nintendogs]
# 183      1             [Call of Duty: Black Ops II]
# 3332     1                  [Red Dead Redemption 2]
# 3367     1                  [New Super Mario Bros.]
# 204      1                     [Grand Theft Auto V]
# 3438     1                     [Grand Theft Auto V]
# 309      1                     [Grand Theft Auto V]
# 169      1                     [Grand Theft Auto V]
# 119      1  [Pokemon Omega Ruby and Alpha Sapphire]
# 3467     1  [Pokemon Omega Ruby and Alpha Sapphire]
# 185      1  [Pokemon Omega Ruby and Alpha Sapphire]
# 277      1  [Pokemon Omega Ruby and Alpha Sapphire]
# 3380     1              [Call of Duty: Black Ops 3]
# 229      1              [Call of Duty: Black Ops 3]
# 47       1              [Call of Duty: Black Ops 3]
# 310      1              [Call of Duty: Black Ops 3]
# 55       1                       [Pokemon Sun/Moon]
# 311      1                       [Pokemon Sun/Moon]
# 168      1                       [Pokemon Sun/Moon]
# 3386     1                       [Pokemon Sun/Moon]
# 67       1                     [Call of Duty: WWII]
# 3424     1                     [Call of Duty: WWII]
# 3403     1             [Call of Duty: Black Ops II]
# 142      1                     [Call of Duty: WWII]
# 3397     1             [Call of Duty: Black Ops II]
# 128      1                  [New Super Mario Bros.]
# 275      1                             [Wii Sports]
# 3482     1                             [Wii Sports]
# 107      1                             [Wii Sports]
# 3468     1                             [Wii Sports]
# ...    ...                                      ...
# 5223   100                                 [NHL 16]
# 5278   100                             [Diablo III]
# 5286   100                         [Gran Turismo 5]
# 5297   100                        [Dante's Inferno]
# 1748   100   [The Legend of Spyro: A New Beginning]
# 3289   100                           [Cooking Mama]
# 3267   100                    [Batman: Arkham City]
# 3255   100                    [Super Mario 3D Land]
# 3293   100                    [Super Mario 3D Land]
# 3202   100                          [Madden NFL 17]
# 3298   100                    [LEGO Jurassic World]
# 3281   100                    [LEGO Jurassic World]
# 3111   100                              [Fallout 3]
# 2862   100                    [LEGO Jurassic World]
# 3297   100                    [Batman: Arkham City]
# 4751   100                         [SoulCalibur IV]
# 3238   100                          [Quantum Break]
# 3268   100                          [Zumba Fitness]
# 3135   100                         [SoulCalibur IV]
# 3273   100                              [Fallout 3]
# 4945   100                           [uDraw Studio]
# 5296   100              [Need for Speed: ProStreet]
# 3239   100                    [Batman: Arkham City]
# 3240   100             [Call of Duty: Black Ops II]
# 3159   100                    [Super Mario 3D Land]
# 5149   100                          [Zumba Fitness]
# 5176   100                            [Viva Pinata]
# 5200   100                           [Cooking Mama]
# 5234   100                                 [NHL 17]
# 2649   100               [Assassin's Creed Origins]
#
#                                        company_genre  year  console  \
# 0                               Nintendo, Simulation  2006     (DS)
# 183                              Activision, Shooter  2012   (X360)
# 3332          Take-Two Interactive, Action-Adventure  2018    (PS4)
# 3367                              Nintendo, Platform  2006     (DS)
# 204                     Take-Two Interactive, Action  2013    (PS3)
# 3438                    Take-Two Interactive, Action  2013   (X360)
# 309                     Take-Two Interactive, Action  2013    (PS3)
# 169                     Take-Two Interactive, Action  2013    (PS3)
# 119                           Nintendo, Role-Playing  2014    (3DS)
# 3467                          Nintendo, Role-Playing  2014    (3DS)
# 185                           Nintendo, Role-Playing  2014    (3DS)
# 277                           Nintendo, Role-Playing  2014    (3DS)
# 3380                             Activision, Shooter  2015    (PS4)
# 229                              Activision, Shooter  2015    (PS4)
# 47                               Activision, Shooter  2015    (PS4)
# 310                              Activision, Shooter  2015    (PS4)
# 55                            Nintendo, Role-Playing  2016    (3DS)
# 311                           Nintendo, Role-Playing  2016    (3DS)
# 168                           Nintendo, Role-Playing  2016    (3DS)
# 3386                          Nintendo, Role-Playing  2016    (3DS)
# 67                               Activision, Shooter  2017    (PS4)
# 3424                             Activision, Shooter  2017    (PS4)
# 3403                             Activision, Shooter  2012   (X360)
# 142                              Activision, Shooter  2017    (PS4)
# 3397                             Activision, Shooter  2012   (X360)
# 128                               Nintendo, Platform  2006     (DS)
# 275                                 Nintendo, Sports  2007    (Wii)
# 3482                                Nintendo, Sports  2007    (Wii)
# 107                                 Nintendo, Sports  2008    (Wii)
# 3468                                Nintendo, Sports  2008    (Wii)
# ...                                              ...   ...      ...
# 5223                         Electronic Arts, Sports  2015   (XOne)
# 5278                        Activision, Role-Playing  2013    (PS3)
# 5286             Sony Computer Entertainment, Racing  2011    (PS3)
# 5297                         Electronic Arts, Action  2010    (PS3)
# 1748                         Vivendi Games, Platform  2006     (DS)
# 3289                           505 Games, Simulation  2006     (DS)
# 3267  Warner Bros. Interactive Entertainment, Action  2013    (PS3)
# 3293        166     [803,356]  [10,022,815]
# 3202         71     [585,345]   [3,253,504]
# 3298         30     [743,124]     [743,124]
# 3281         30     [743,124]     [743,124]
# 3111         62     [883,714]   [2,770,049]
# 2862         30     [743,124]     [743,124]
# 3297        116     [777,074]   [4,846,970]
# 4751         23   [1,037,986]   [1,037,986]
# 3238         39     [650,985]     [650,985]
# 3268         59     [912,644]   [1,174,801]
# 3135         23   [1,037,986]   [1,037,986]
# 3273         62     [883,714]   [2,770,049]
# 4945          7     [912,853]     [912,853]
# 5296         60     [465,849]     [868,888]
# 3239        116     [777,074]   [4,846,970]
# 3240          7     [793,027]     [793,027]
# 3159        166     [803,356]  [10,022,815]
# 5149         59     [912,644]   [1,174,801]
# 5176         60     [658,935]     [858,732]
# 5200         41     [259,806]     [259,806]
# 5234         16     [228,089]     [228,089]
# 2649         62     [560,485]   [2,474,124]
#
# [5300 rows x 8 columns]

# %%
df_5
# Out:
#       rank                                      video_game  \
# 0        1                                    [Nintendogs]
# 1        2                         [New Super Mario Bros.]
# 2        3                                  [Gears of War]
# 3        4                                 [Madden NFL 07]
# 4        5  [Brain Age: Train Your Brain in Minutes a Day]
# 5        6                                    [Wii Sports]
# 6        7  [Tom Clancy's Ghost Recon Advanced Warfighter]
# 7        8                                 [Mario Kart DS]
# 8        9        [The Legend of Zelda: Twilight Princess]
# 9       10                [The Elder Scrolls IV: Oblivion]
# 10      11                   [Animal Crossing: Wild World]
# 11      12                                [Call of Duty 3]
# 12      13                             [Big Brain Academy]
# 13      14     [Pokemon Mystery Dungeon: Blue Rescue Team]
# 14      15        [Grand Theft Auto: Liberty City Stories]
# 15      16                                [Call of Duty 2]
# 16      17                                    [Saints Row]
# 17      18                           [Fight Night Round 3]
# 18      19                              [NCAA Football 07]
# 19      20                             [Yoshi's Island DS]
# 20      21                                   [Dead Rising]
# 21      22               [Tom Clancy's Rainbow Six: Vegas]
# 22      23                                [Pokemon Ranger]
# 23      24                                 [Madden NFL 07]
# 24      25      [Tom Clancy's Splinter Cell: Double Agent]
# 25      26                             [Super Mario 64 DS]
# 26      27                         [Metroid Prime Hunters]
# 27      28                            [Mario Hoops 3 on 3]
# 28       1                         [Red Dead Redemption 2]
# 29      29             [Need for Speed: Most Wanted 5-1-0]
# ...    ...                                             ...
# 5270    99                           [Red Dead Redemption]
# 5271    98             [LEGO Star Wars: The Complete Saga]
# 5272    96                              [Metroid: Other M]
# 5273    96                                [Call of Duty 3]
# 5274    98                                 [Madden NFL 10]
# 5275    96             [Blazing Angels: Squadrons of WWII]
# 5276    98                                 [EA Sports UFC]
# 5277    97                     [Personal Trainer: Cooking]
# 5278   100                                    [Diablo III]
# 5279    99                      [SOCOM 4: U.S. Navy SEALs]
# 5280    97                             [Super Mario 64 DS]
# 5281    97  [Ratchet & Clank Future: Tools of Destruction]
# 5282    99                                 [Guitar Hero 5]
# 5283    97             [MX vs. ATV Unleashed: On the Edge]
# 5284    99               [Assassin's Creed IV: Black Flag]
# 5285    98                                 [NERF N-Strike]
# 5286   100                                [Gran Turismo 5]
# 5287    98                    [Gold's Gym: Cardio Workout]
# 5288    98                       [Naruto: Ninja Council 3]
# 5289   100                           [Grand Theft Auto IV]
# 5290    98                                [Call of Duty 3]
# 5291   100                           [Super Mario 3D Land]
# 5292    99                     [Major League Baseball 2K8]
# 5293    99                                   [Borderlands]
# 5294    99                                 [Madden NFL 07]
# 5295    99    [Lord of the Rings: Battle for Middle-Earth]
# 5296   100                     [Need for Speed: ProStreet]
# 5297   100                               [Dante's Inferno]
# 5298   100                    [Rapala Tournament Fishing!]
# 5299   100          [The Legend of Spyro: A New Beginning]
#
#                                company_genre  year  console  weeks_out  \
# 0                       Nintendo, Simulation  2006     (DS)         71
# 1                         Nintendo, Platform  2006     (DS)         33
# 2                         Microsoft, Shooter  2006   (X360)          8
# 3                    Electronic Arts, Sports  2006   (X360)         19
# 4                             Nintendo, Misc  2006     (DS)         37
# 5                           Nintendo, Sports  2006    (Wii)          6
# 6                           Ubisoft, Shooter  2006   (X360)         43
# 7                           Nintendo, Racing  2006     (DS)         59
# 8                        Nintendo, Adventure  2006    (Wii)          6
# 9         Take-Two Interactive, Role-Playing  2006   (X360)         41
# 10                      Nintendo, Simulation  2006     (DS)         56
# 11                       Activision, Shooter  2006   (X360)          8
# 12                            Nintendo, Misc  2006     (DS)         30
# 13                    Nintendo, Role-Playing  2006     (DS)         15
# 14              Take-Two Interactive, Action  2006    (PSP)         62
# 15                       Activision, Shooter  2006   (X360)         59
# 16                               THQ, Action  2006   (X360)         18
# 17                 Electronic Arts, Fighting  2006   (X360)         45
# 18                   Electronic Arts, Sports  2006   (X360)         24
# 19                        Nintendo, Platform  2006     (DS)          7
# 20                            Capcom, Action  2006   (X360)         21
# 21                          Ubisoft, Shooter  2006   (X360)          6
# 22                    Nintendo, Role-Playing  2006     (DS)          9
# 23                   Electronic Arts, Sports  2006    (PSP)         19
# 24                           Ubisoft, Action  2006   (X360)         11
# 25                        Nintendo, Platform  2006     (DS)        110
# 26                         Nintendo, Shooter  2006     (DS)         41
# 27                          Nintendo, Sports  2006     (DS)         16
# 28    Take-Two Interactive, Action-Adventure  2018    (PS4)         10
# 29                   Electronic Arts, Racing  2006    (PSP)         59
# ...                                      ...   ...      ...        ...
# 5270            Take-Two Interactive, Action  2013   (X360)        190
# 5271                       LucasArts, Action  2011    (Wii)        217
# 5272                        Nintendo, Action  2010    (Wii)         18
# 5273                     Activision, Shooter  2007   (X360)         60
# 5274                 Electronic Arts, Sports  2009    (Wii)         21
# 5275                     Ubisoft, Simulation  2006   (X360)         41
# 5276                 Electronic Arts, Sports  2014    (PS4)         28
# 5277                          Nintendo, Misc  2008     (DS)          6
# 5278                Activision, Role-Playing  2013    (PS3)         18
# 5279    Sony Computer Entertainment, Shooter  2011    (PS3)         37
# 5280                      Nintendo, Platform  2010     (DS)        319
# 5281   Sony Computer Entertainment, Platform  2007    (PS3)         10
# 5282                        Activision, Misc  2009    (Wii)         18
# 5283                             THQ, Racing  2006    (PSP)         44
# 5284                         Ubisoft, Action  2014    (PS4)         59
# 5285                Electronic Arts, Shooter  2008    (Wii)         10
# 5286     Sony Computer Entertainment, Racing  2011    (PS3)         58
# 5287                         Ubisoft, Sports  2010    (Wii)         93
# 5288                    D3 Publisher, Action  2007     (DS)         32
# 5289            Take-Two Interactive, Action  2009   (X360)         88
# 5290                     Activision, Shooter  2006    (Wii)          7
# 5291                      Nintendo, Platform  2014    (3DS)        163
# 5292            Take-Two Interactive, Sports  2008   (X360)         44
# 5293           Take-Two Interactive, Shooter  2010   (X360)         63
# 5294                 Electronic Arts, Sports  2007   (X360)         71
# 5295               Electronic Arts, Strategy  2006   (X360)         26
# 5296                 Electronic Arts, Racing  2008   (X360)         60
# 5297                 Electronic Arts, Action  2010    (PS3)         47
# 5298                      Activision, Sports  2007    (Wii)         58
# 5299                 Vivendi Games, Platform  2006     (DS)         11
#
#        yearly_sale    total_sale
# 0      [2,109,928]   [3,594,975]
# 1      [1,913,739]   [1,913,739]
# 2      [1,785,997]   [1,785,997]
# 3      [1,160,526]   [1,160,526]
# 4      [1,075,980]   [1,075,980]
# 5      [1,045,442]   [1,045,442]
# 6        [918,447]     [918,447]
# 7        [874,373]   [1,720,791]
# 8        [864,192]     [864,192]
# 9        [758,068]     [758,068]
# 10       [729,536]     [972,181]
# 11       [727,960]     [727,960]
# 12       [697,859]     [697,859]
# 13       [687,964]     [687,964]
# 14       [599,479]   [1,256,710]
# 15       [545,666]   [1,045,710]
# 16       [535,463]     [535,463]
# 17       [525,214]     [525,214]
# 18       [514,454]     [514,454]
# 19       [501,010]     [501,010]
# 20       [477,287]     [477,287]
# 21       [445,225]     [445,225]
# 22       [444,320]     [444,320]
# 23       [444,011]     [444,011]
# 24       [429,986]     [429,986]
# 25       [424,846]   [1,703,546]
# 26       [405,698]     [405,698]
# 27       [385,375]     [385,375]
# 28    [13,940,203]  [13,940,203]
# 29       [374,911]     [611,249]
# ...            ...           ...
# 5270     [334,116]   [3,176,579]
# 5271     [440,606]   [2,771,841]
# 5272     [411,523]     [411,523]
# 5273     [263,003]     [990,963]
# 5274     [389,244]     [389,244]
# 5275     [158,238]     [158,238]
# 5276     [305,713]     [305,713]
# 5277     [473,764]     [473,764]
# 5278     [331,691]     [331,691]
# 5279     [440,125]     [440,125]
# 5280     [410,381]   [3,930,665]
# 5281     [260,419]     [260,419]
# 5282     [388,155]     [388,155]
# 5283     [157,107]     [157,107]
# 5284     [305,096]     [825,162]
# 5285     [473,085]     [473,085]
# 5286     [435,478]   [1,676,718]
# 5287     [407,890]     [810,821]
# 5288     [256,692]     [256,692]
# 5289     [386,126]   [4,030,045]
# 5290     [156,095]     [156,095]
# 5291     [304,809]   [4,173,769]
# 5292     [470,114]     [470,114]
# 5293     [406,505]   [1,312,021]
# 5294     [251,755]   [1,412,281]
# 5295     [155,731]     [155,731]
# 5296     [465,849]     [868,888]
# 5297     [403,326]     [403,326]
# 5298     [249,993]     [298,893]
# 5299     [155,571]     [155,571]
#
# [5300 rows x 8 columns]
